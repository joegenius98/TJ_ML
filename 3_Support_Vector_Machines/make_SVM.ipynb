# %%
#core data science packages
import pandas as pd
import numpy as np

#SVM models
from sklearn import svm
#accuracy scoring
from sklearn.metrics import accuracy_score

#graphing
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)
# %matplotlib inline

# from: https://github.com/tjmachinelearning/yogurt-svm/blob/master/greek_or_not.ipynb

# %%
train_data = pd.read_csv('training.csv').dropna()

# %%
train_data.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 1           270       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           272       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           275       1                            McCarthy, Mr. Timothy J
# 10          279       3                    Sandstrom, Miss. Marguerite Rut
# 11          280       1                           Bonnell, Miss. Elizabeth
#
#        Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Survived
# 1   female  38.0      1      0  PC 17599  71.2833   C85        C         1
# 3   female  35.0      1      0    113803  53.1000  C123        S         1
# 6     male  54.0      0      0     17463  51.8625   E46        S         0
# 10  female   4.0      1      1   PP 9549  16.7000    G6        S         1
# 11  female  58.0      0      0    113783  26.5500  C103        S         1

# %%
#change these variables
f1 = 'Fare'
f2 = 'Age'

sns.lmplot(x=f1, y=f2, data=train_data, hue='Survived', fit_reg=False, 
           scatter_kws={"s": 100}, markers=['o', 'x'])

# %%
real_train_data, labels = train_data.loc[:, ['Fare', 'Age']], train_data.loc[:, 'Survived']

# %%
print(real_train_data.head())
print('\n')
print(labels.head())
# Out:
# Fare   Age
# 1   71.2833  38.0
# 3   53.1000  35.0
# 6   51.8625  54.0
# 10  16.7000   4.0
# 11  26.5500  58.0
#
#
# 1     1
# 3     1
# 6     0
# 10    1
# 11    1
# Name: Survived, dtype: int64

# %%
clf = svm.SVC()
clf.fit(real_train_data, labels)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
